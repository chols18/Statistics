# %% [markdown]
# # <b> LISTS AND TUPLES <hr style="border:2.5px solid rgba(255, 0, 0, 1)" ></hr>

# %% [markdown]
# <b>NICHOLAI ESTARES</b><br>
# Comptech Student T09<br>
# 12/9/2025

# %% [markdown]
# ## <b>CREATING A LIST <hr style="border:2.5px solid rgba(255, 0, 0, 1)" ></hr>

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[-3]
# Out:
# 3

# %%
mixed_list = [10,"AG",20,2.5,True]
mixed_list
# Out:
# [10, 'AG', 20, 2.5, True]

# %%
fruits = ['Apple', 'Banana', 'Grapes']
fruits
# Out:
# ['Apple', 'Banana', 'Grapes']

# %%
fruits[-2] = 'Orange'
fruits
# Out:
# ['Apple', 'Orange', 'Grapes']

# %%
fruits.append('bayabas')
fruits
# Out:
# ['Apple', 'Orange', 'Grapes', 'bayabas']

# %%
fruits.insert(1,'blueberry')
fruits
# Out:
# ['Apple', 'blueberry', 'Orange', 'Grapes', 'bayabas']

# %%
'Apple' in fruits
# Out:
# True

# %%
'Dragonfruit' in fruits
# Out:
# False

# %%
fruits.remove('blueberry')

# %%
fruits.pop(0)
# Out:
# 'Apple'

# %% [markdown]
# ## <b>sort() and sorted() <hr style="border:2.5px solid rgba(255, 0, 0, 1)" ></hr>

# %%
list = [3,4,1,5,2]
list
# Out:
# [3, 4, 1, 5, 2]

# %%
sorted(list)
list
# Out:
# [3, 4, 1, 5, 2]

# %%
list.sort(reverse=True)
list
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## <b>SLICING <hr style="border:2.5px solid rgba(255, 0, 0, 1)" ></hr>

# %%
numbers = [18,7,2,1,9,21,51,90,99]
numbers
# Out:
# [18, 7, 2, 1, 9, 21, 51, 90, 99]

# %%
len(numbers)
# Out:
# 9

# %%
sub = numbers[1:5]
sub
# Out:
# [7, 2, 1, 9]

# %%
numbers[0:8:2]
# Out:
# [18, 2, 9, 51]

# %% [markdown]
# ## <b>TUPLE <hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)
